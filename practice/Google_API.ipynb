# %% [markdown]
# # Google Maps and Places API

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID      City Country                 Date    Lat     Lng  Max Temp  \
# 0        0    Liwale      TZ  2020-11-29 21:23:45  -9.77   37.93     71.85
# 1        1  Vanavara      RU  2020-11-29 21:23:45  60.34  102.28      3.29
# 2        2  Victoria      HK  2020-11-29 21:23:06  22.29  114.16     64.00
# 3        3      Nuuk      GL  2020-11-29 21:18:57  64.18  -51.72     30.20
# 4        4   Aklavik      CA  2020-11-29 21:23:46  68.22 -135.01     -2.20
#
#    Humidity  Cloudiness  Wind Speed
# 0        91           0        4.54
# 1        94         100        6.13
# 2        69          99       10.13
# 3        68         100       24.16
# 4        77         100        3.36

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# 1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add
heat_layer = gmaps.heatmap_layer(locations, weights=temps,dissipating=False,
max_intensity=300, point_radius=4)
# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Percent Humidity Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating = False, max_intensity =300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights = clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights = wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Get Vacation Criteria

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]

# %%
preferred_cities_df.head(10)
# Out:
#     City_ID       City Country                 Date    Lat     Lng  Max Temp  \
# 0         0     Liwale      TZ  2020-11-29 21:23:45  -9.77   37.93     71.85
# 5         5     Najran      SA  2020-11-29 21:19:08  17.49   44.13     73.40
# 6         6       Miri      MY  2020-11-29 21:23:47   4.41  114.01     75.20
# 8         8      Kapaa      US  2020-11-29 21:23:48  22.08 -159.32     77.00
# 9         9       Yako      BF  2020-11-29 21:23:48  12.97   -2.27     80.46
# 18       18    Rikitea      PF  2020-11-29 21:23:53 -23.12 -134.97     76.08
# 20       20  Hithadhoo      MV  2020-11-29 21:20:17  -0.60   73.08     82.11
# 24       24    Salalah      OM  2020-11-29 21:23:55  17.02   54.09     77.00
# 27       27     Linden      GY  2020-11-29 21:22:50   6.00  -58.30     78.80
# 30       30   Eirunepe      BR  2020-11-29 21:23:57  -6.66  -69.87     82.65
#
#     Humidity  Cloudiness  Wind Speed
# 0         91           0        4.54
# 5         38          75        3.56
# 6         94          40        2.24
# 8         78          75       14.99
# 9         26           0        7.63
# 18        81          79       11.18
# 20        69         100        7.99
# 24        73          75        2.24
# 27        94          75        4.70
# 30        84         100        2.13

# %%
#determine if there are any null values.
preferred_cities_df.count()
# Out:
# City_ID       196
# City          196
# Country       195
# Date          196
# Lat           196
# Lng           196
# Max Temp      196
# Humidity      196
# Cloudiness    196
# Wind Speed    196
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#          City Country  Max Temp    Lat     Lng Hotel Name
# 0      Liwale      TZ     71.85  -9.77   37.93
# 5      Najran      SA     73.40  17.49   44.13
# 6        Miri      MY     75.20   4.41  114.01
# 8       Kapaa      US     77.00  22.08 -159.32
# 9        Yako      BF     80.46  12.97   -2.27
# 18    Rikitea      PF     76.08 -23.12 -134.97
# 20  Hithadhoo      MV     82.11  -0.60   73.08
# 24    Salalah      OM     77.00  17.02   54.09
# 27     Linden      GY     78.80   6.00  -58.30
# 30   Eirunepe      BR     82.65  -6.66  -69.87

# %%
# Dependencies and Setup
import requests
import gmaps
# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
"radius": 5000,
"types": "lodge",
"key": g_key,
"location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJbwWft_Gr4QzZYeaBVgHI8jo5lOxzsj5OYvBlu4FCN0S6oZfumz7U1oRQjBATmHOwloeyaMgeixoigqw3JckOFwn9ul5JZnZUiZNPACbyJ9UlaGHNjUpIciJi0iRJySkJzsXekOdgOBdgLK3YPJc6zpRG1yjmPKx2-XrYiqgUIwUaM3OofviOymEcA8ZbJzvBE1ZEvU7X8BcetFiFNLjnrA09z3D1-h771sepo-PHaLIYWkVZEmb_psJ4j2Y2hRBWgCk6pvUxKjBIidjUzxwEd7ndcShvVI2L_G0eSGAnT6j7n4zvhAoijmz4ndq22Xx5DKSo6Ll4v5oEt-1cdzvd3k0EyPgsanbhkXEB4aD8tRvl0aGmb4lt8dqbg4rcwMmLxvxiD4cbP_nsm2GgYZ7DGAVapw4vv07szW46KBhTERXdvXWFDEw',
#  'results': [{'geometry': {'location': {'lat': 48.85661400000001,
#      'lng': 2.3522219},
#     'viewport': {'northeast': {'lat': 48.9021449, 'lng': 2.4699208},
#      'southwest': {'lat': 48.815573, 'lng': 2.224199}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Paris',
#    'photos': [{'height': 475,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105303505373661530610">indoorfish</a>'],
#      'photo_reference': 'ATtYBwJwKa2OwBmPpsj0-MlSFaIuYObSZBKqMxH7AL0Ar4TahpT4BXwDZdGL0lN_okp_pRjtQpRvSHhCMRSxiGcpPAP4taxWvE_PrIT1rB0JQogWfo0zGQGiyknIH6Y2ICsdTjxMKy0VWQbc_DikZgTGHXDx1Ju6Kk1Wyfpr_QNMF8Z-nVwL',
#      'width': 710}],
#    'place_id': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#    'reference': 'ChIJD7fiBh9u5kcRYJSMaMOCCwQ',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291502},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'ATtYBwJB85noTGRscvFuC_f_5Hk8lcKsDm3d6b8m6rQxt1NRYd2ReLYS1tiAWmkAYROE3jiv0V_XLeUI9nKjkWTeuUjKGz9eJyLUH6DaY7XvbwmeJmT0B7LMwk9CFxfgWbonKX4CbV5wpJMgCZy9cm_15jUxWHrIcu6iYJiUOkUUxkibAPRm',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 278,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.8595495802915,
#       'lng': 2.347780980291502},
#      'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Britannique',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 546,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Louvre</a>'],
#      'photo_reference': 'ATtYBwL4fPowD98Dk9vpCpBKeS0HAQSRucaxiqmn59-HIG9GNKCjGAD4-iFwSDqxxIPwaINP38OiGg6oVszMTK_oW0m83sOgjxl8zTdEdKwCmtMlckCV33lmLXfE9jdh5b9NewpffrTvf3ir1uOH8B2MRKBjsQt_3DnNJMXsgInWOqzP5egc',
#      'width': 1024}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 379,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8618387802915,
#       'lng': 2.348475730291502},
#      'southwest': {'lat': 48.85914081970851, 'lng': 2.345777769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Les Halles Paris (Apart Hotel Paris)',
#    'permanently_closed': True,
#    'photos': [{'height': 496,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart Hotel Paris)</a>'],
#      'photo_reference': 'ATtYBwLhCITi9IeTLSGNvDhMqiBO4t2uwr2W8kpUP341GE8eGz3kUx2-cy7tId7S3xiRcF1rpn6wwmQXMXu9CbZjopA2OO7KH77colybjQKQgPUcY6uHfxyM3ZX2hzyPpbO7RD86ab_HbD_5Vs88FsHorEaz3v_3Ttwvz16TQm1ZHPQzxHZ6',
#      'width': 745}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 814,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607769, 'lng': 2.3463217},
#     'viewport': {'northeast': {'lat': 48.8620135802915,
#       'lng': 2.347597080291502},
#      'southwest': {'lat': 48.8593156197085, 'lng': 2.344899119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel</a>'],
#      'photo_reference': 'ATtYBwJ4w_WEIGF8bD4qBWx2TbVUAsdl9fNCTNGLfhTVYHT7DW4KZd3065EOdobraHUK06-3tkZoPy08tEp4jY9oaJqY0pnkE1Icx4pRYoSe-z1P41OuCBdUyoGmL-PFW_lTWV7BOOi7WqrtaBPyA6APvU0_fABPzZO8ZV0l-_4ePXH7-MqW',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8G Paris, France',
#     'global_code': '8FW4V86W+8G'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2084,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86034799999999, 'lng': 2.344054},
#     'viewport': {'northeast': {'lat': 48.8616503302915,
#       'lng': 2.345521080291502},
#      'southwest': {'lat': 48.8589523697085, 'lng': 2.342823119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Best Western Premier Ducs de Bourgogne</a>'],
#      'photo_reference': 'ATtYBwKOS-OEnSDL0d1SNPlfqoXn9syisxn-tgQAgK02VieIVkU7_aEAjVU900LH0q1MeqW8li2EtcLtJrKF6eYPs3aCog4bpbBnyrlIbM1GwY1J9wjio_6-HAbKrhA0HtFOVesoayNnYEbtKwDr1_FfKsrc1z381yaORhrh7AX5dUKxJAqF',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 275,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.85380223029149,
#       'lng': 2.348557280291502},
#      'southwest': {'lat': 48.85110426970849, 'lng': 2.345859319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'ATtYBwLy3N3SgjwMnKhEAhIE84MF1luggoQs7JrIAWkKRcSUX-QLFlL7YF4esNUfuW6pPAr1a5qSN0BB6_I01tkqiLNSLJtQnB-6Nq21vtarYYQXOarAwT4FEJN6KlXkyjIHqOcSsg86Qczuvp4pe-KyO7tdmps8EwhyBMLLvlGLE36OxfMd',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8600866, 'lng': 2.3533543},
#     'viewport': {'northeast': {'lat': 48.86148808029149,
#       'lng': 2.354740780291502},
#      'southwest': {'lat': 48.85879011970849, 'lng': 2.352042819708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Beaubourg',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2684,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115421447635584539926">Hôtel Beaubourg</a>'],
#      'photo_reference': 'ATtYBwLDn9hG-3YWu7IiPjx9E6SW-Jfe5NvbbgiIZOGJcmRnHRYDUrDK0rUFY-ifZiSF2REqoeOj62AhuzZ6cSNgofvPkjDeqO4CfEz_LIIFQesjb97jUcjbtO61ITdeVdAK2MNjBmfEzEKEbFRmk3hCPwPGzySB4ImxGH9D5__7c_sKV4mL',
#      'width': 5937}],
#    'place_id': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'plus_code': {'compound_code': 'V963+28 Paris, France',
#     'global_code': '8FW4V963+28'},
#    'rating': 4.1,
#    'reference': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 130,
#    'vicinity': '11 Rue Simon le Franc, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8532461, 'lng': 2.345776},
#     'viewport': {'northeast': {'lat': 48.85464993029149,
#       'lng': 2.347159130291502},
#      'southwest': {'lat': 48.85195196970849, 'lng': 2.344461169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Les Rives de Notre-Dame Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107978996303311443904">Les Rives de Notre-Dame Hotel</a>'],
#      'photo_reference': 'ATtYBwJvuZ2oVbHV5NI27wnde-4uYvLYVw1QAe6yMmvMW8vIduFRFw9Srei0JQL8JPcmt7lyHIXLXGQvTkLAN_aZwOp22QeEbCLu1uML4uCuq_gs1ZioR5NoTfXO9IVPJBkLUTf3UweJdTjxEet2-cxRxV88T3KavNzAU7GdzG6CQc5yLKdB',
#      'width': 3264}],
#    'place_id': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'plus_code': {'compound_code': 'V83W+78 Paris, France',
#     'global_code': '8FW4V83W+78'},
#    'rating': 4.6,
#    'reference': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 87,
#    'vicinity': '15 Quai Saint-Michel, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.859876, 'lng': 2.347049},
#     'viewport': {'northeast': {'lat': 48.8612083302915,
#       'lng': 2.348480530291502},
#      'southwest': {'lat': 48.8585103697085, 'lng': 2.345782569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Hôtel Des Ducs D'Anjou",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115209143941459061727">Hotel Des Ducs D&#39;Anjou</a>'],
#      'photo_reference': 'ATtYBwKyvuOjpejQ4PxJv_bU94_oPhkJozmxGjo2bkqlecpnaYHF22NsIEwCZzueC9a6FU8ceKXB7FHXWkoWtT525AVf_Z6WsehAsvyOgWZhM78h9mE-uGmoDZTgxLmNO8mqrCa9WIJE9tRDx68vbKbNpEcZkz44gb9smVYCNneKlxo5K4V2',
#      'width': 1352}],
#    'place_id': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'plus_code': {'compound_code': 'V85W+XR Paris, France',
#     'global_code': '8FW4V85W+XR'},
#    'rating': 4,
#    'reference': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 283,
#    'vicinity': '1 Rue Sainte-Opportune, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'ATtYBwLIrIp15XHqCC5z33XoOap1myl0qfzpUCKMEMOmTGJxHxw_VY_wk2yzq-eMvHMNELH7i0yHkI7m0QADb-VDaKs3wXsjqYs2JurNdqNAR7WpXGzWJ0ZtGbOMBbXHc_lMvTLwii4rFtjUuaEEzP-z3r7NCiEx1X8UuJm34q8P2PI4uRnv',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 320,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8515299, 'lng': 2.3487001},
#     'viewport': {'northeast': {'lat': 48.8529346302915,
#       'lng': 2.349991380291502},
#      'southwest': {'lat': 48.8502366697085, 'lng': 2.347293419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Melia Paris Notre-Dame',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107411481479353323307">James Mann</a>'],
#      'photo_reference': 'ATtYBwJ9hmHiwp0br-I_CKiFMTtNUaoBnltANPAvk7ce9DCSkDtyiNsPn8dI46iV7dFgZrkEH1_52cB3zaLTseeb9USAgjXfD6bvXv7i3BR7M3IMW5XioBlmpBDARjTmNUE25SrHKIbmAzTMm4_vp7W96xJssxOD9wUQN3goeQQ4pnqcXoJZ',
#      'width': 4160}],
#    'place_id': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'plus_code': {'compound_code': 'V82X+JF Paris, France',
#     'global_code': '8FW4V82X+JF'},
#    'rating': 4.4,
#    'reference': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 228,
#    'vicinity': "7 Rue de l'Hôtel Colbert, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8514399, 'lng': 2.3495127},
#     'viewport': {'northeast': {'lat': 48.8527649302915,
#       'lng': 2.350851280291502},
#      'southwest': {'lat': 48.8500669697085, 'lng': 2.348153319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Les Degrés de Notre Dame',
#    'photos': [{'height': 1984,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115564994803632359392">christophe etter</a>'],
#      'photo_reference': 'ATtYBwLD4EZgsqq1DU-b3pQFGjmi7xK_cNT6P3acosDY_RIjuUY2WMZkwXE3FxjzbSlrmJJcuGHebgA80yXYkPJ0etrKpuSKomBm-I_J5npaMeJWTPznqDXnGeKgUHTssCicKjth7x6u_KZrniE7nxUINNC8aQ2WmKB5ih9qU-LflzqI_UUI',
#      'width': 3968}],
#    'place_id': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'plus_code': {'compound_code': 'V82X+HR Paris, France',
#     'global_code': '8FW4V82X+HR'},
#    'rating': 3.8,
#    'reference': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 76,
#    'vicinity': '10 Rue des Grands Degrés, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8518743, 'lng': 2.3463436},
#     'viewport': {'northeast': {'lat': 48.8532481802915,
#       'lng': 2.347596830291502},
#      'southwest': {'lat': 48.8505502197085, 'lng': 2.344898869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Henri IV Rive Gauche',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110843539741047032038">Paul Schalow</a>'],
#      'photo_reference': 'ATtYBwI3Or-vsMEu2u1Lkq2_AxD5AS55RWwrn-Sn92uKlhwu-zFBBtS37LstFn1h0Fgi4aYtJcCjy7AGX9I50yHQDPywqXXKfizFHUeRUpcOO22OI7o0YLbl2V3H2O_HSM6hgVr_7LMEcYovEE_Gbj7kwdOkZEFmrqZb9ptQuDtDj3hIG4u2',
#      'width': 4032}],
#    'place_id': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'plus_code': {'compound_code': 'V82W+PG Paris, France',
#     'global_code': '8FW4V82W+PG'},
#    'rating': 4.5,
#    'reference': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 129,
#    'vicinity': 'Rue Saint-Jacques, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85305029999999, 'lng': 2.346607},
#     'viewport': {'northeast': {'lat': 48.8544437802915,
#       'lng': 2.347982880291502},
#      'southwest': {'lat': 48.8517458197085, 'lng': 2.345284919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Notre-Dame Saint Michel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1703,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114461086709426724325">Hôtel Notre-Dame Saint Michel</a>'],
#      'photo_reference': 'ATtYBwIQBRmlRGYPOSVWUfp9A3bTwfutlLJtrBOrv9IOwZk3Cg2j4Y4vE2kPF2z-BeLdgaPjS3oaHRoEahNrxRTdweiDndK2Fp798Zl-sG7mbCRAfCCLSIv07kHzhlAEu1FJdG1XECfucMwKvWElLb8QLcOhens-V7Gc8FqPNbClrkNhrQrc',
#      'width': 2500}],
#    'place_id': 'ChIJI-tW--Bx5kcRJk2RrpFCQyc',
#    'plus_code': {'compound_code': 'V83W+6J Paris, France',
#     'global_code': '8FW4V83W+6J'},
#    'rating': 4,
#    'reference': 'ChIJI-tW--Bx5kcRJk2RrpFCQyc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1096,
#    'vicinity': '1 Quai Saint-Michel, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8565138, 'lng': 2.3561437},
#     'viewport': {'northeast': {'lat': 48.8578126302915,
#       'lng': 2.357464830291502},
#      'southwest': {'lat': 48.8551146697085, 'lng': 2.354766869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel France Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1511,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104343544959367387958">Hôtel France Louvre</a>'],
#      'photo_reference': 'ATtYBwJCtnCDe0MwMD5C-4IDJ8_nxh4cq24Ln2sIW_Y_YM2i8PgegqilVAp_IdYpmz21WRNNWm4_E0GgMfv-Q_2SQTl2R_Dw9g5jdW2IrbCs4-UP29JWAoouRRlGwYSVcVkfa_AocYnZJpx69WYarJxO2mEJCaO-Vut1RH_kxACw0ZJJBAjh',
#      'width': 1511}],
#    'place_id': 'ChIJRZOcrgJu5kcRNHLaohZ3YRI',
#    'plus_code': {'compound_code': 'V944+JF Paris, France',
#     'global_code': '8FW4V944+JF'},
#    'rating': 3.5,
#    'reference': 'ChIJRZOcrgJu5kcRNHLaohZ3YRI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 290,
#    'vicinity': '40 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85658710000001, 'lng': 2.3558178},
#     'viewport': {'northeast': {'lat': 48.85788813029151,
#       'lng': 2.357140180291502},
#      'southwest': {'lat': 48.85519016970851, 'lng': 2.354442219708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel De Nice',
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105503356634687621691">Hôtel De Nice</a>'],
#      'photo_reference': 'ATtYBwJmPqhkec7naSOKuC8P-UvQy0L7L-0AtvkAnsEeQc7bM4R4LdilYaopqBsD-TrnExbFLgxJRLY2POdEw1XuyLPfngLB0e6UbA3vABzi29D8dc0Cbpq-HIcyP3NwuBnxJJKBAWSyP1vM_OQUzHcqNQJcO18b6h3kvoo_fRRLk7hxqzMW',
#      'width': 1024}],
#    'place_id': 'ChIJ2_H0Uh1u5kcR_qHEHINNe7E',
#    'plus_code': {'compound_code': 'V944+J8 Paris, France',
#     'global_code': '8FW4V944+J8'},
#    'rating': 4.2,
#    'reference': 'ChIJ2_H0Uh1u5kcR_qHEHINNe7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 162,
#    'vicinity': '42 Bis Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8557234, 'lng': 2.3451467},
#     'viewport': {'northeast': {'lat': 48.8569468302915,
#       'lng': 2.346923280291502},
#      'southwest': {'lat': 48.8542488697085, 'lng': 2.344225319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'Palais de Justice de Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114485406284952292491">Silvia FN</a>'],
#      'photo_reference': 'ATtYBwKEIbiocH2XXK8faVIfa5TAL9ib0RWmwFmMWc4Lkvdl5fRDaTGG5UlKL7wTmFbjGu_UUj6HQn6tD99bCjaL3EaEJJcGcK5iQzi0Gxiv8g4Byj4pVFZ0N5hGPd9hP6IRViZjXAwocUiCzjyLdo0vxLrgbQ3YfWZPXRcgwK6P0-OtNB5U',
#      'width': 4032}],
#    'place_id': 'ChIJk3npIuBx5kcRkqWnNdgP57Y',
#    'plus_code': {'compound_code': 'V84W+73 Paris, France',
#     'global_code': '8FW4V84W+73'},
#    'rating': 4.2,
#    'reference': 'ChIJk3npIuBx5kcRkqWnNdgP57Y',
#    'scope': 'GOOGLE',
#    'types': ['tourist_attraction',
#     'courthouse',
#     'local_government_office',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 272,
#    'vicinity': '10 Boulevard du Palais, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85259199999999, 'lng': 2.354225},
#     'viewport': {'northeast': {'lat': 48.85397178029149,
#       'lng': 2.355598930291502},
#      'southwest': {'lat': 48.85127381970849, 'lng': 2.352900969708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Hôtel Saint-Louis en l'Isle",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108387603920056908646">Tony De Marco</a>'],
#      'photo_reference': 'ATtYBwKKfyPPTRhW7n5Uh1nVL8_TkOJtyBceW7k3Rl5uUVHDdVOro6A4t5HlYhPfhiaWsAA6Zwy_x1EZ5oRBrS6kg0I7oICLx_PnOVnk3yZ-HXceIIja0cxu1zcC5hxMrZXo5rSraj_32pG_0Fzj1jljMGD2UpXgdMOTQ3KRTP-KNYZIN5H1',
#      'width': 4032}],
#    'place_id': 'ChIJnw7-O-Nx5kcRRmqhwXhpr_w',
#    'plus_code': {'compound_code': 'V933+2M Paris, France',
#     'global_code': '8FW4V933+2M'},
#    'rating': 4.4,
#    'reference': 'ChIJnw7-O-Nx5kcRRmqhwXhpr_w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 98,
#    'vicinity': "75 Rue Saint-Louis en l'Île, Paris"},
#   {'geometry': {'location': {'lat': 48.8582383, 'lng': 2.274943399999999},
#     'viewport': {'northeast': {'lat': 48.8803319, 'lng': 2.301587},
#      'southwest': {'lat': 48.8338419, 'lng': 2.2241989}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#    'name': '16th arrondissement of Paris',
#    'photos': [{'height': 2666,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102283397557820718012">Владимир Йосифов</a>'],
#      'photo_reference': 'ATtYBwKG4p9j5T3NZ200GrjymZ2jhu5UdGzWYttFN14WZLu20AvxcU3RT-bIWNK7Q5-1K1bqe2-FaeUFaCduBGr8Dcn5LrpDa_1hfkXc22mqcPFxYglnmSNSQjATB5A0pxvOnK5duF2pUsJxu0SqeYHTE0hcMI0XhrrO8AD0t26h-CYLf7qO',
#      'width': 3024}],
#    'place_id': 'ChIJ6VVDJrN65kcRQBuUaMOCCwU',
#    'reference': 'ChIJ6VVDJrN65kcRQBuUaMOCCwU',
#    'scope': 'GOOGLE',
#    'types': ['sublocality_level_1', 'sublocality', 'political'],
#    'vicinity': '16th arrondissement of Paris'}],
#  'status': 'OK'}

# %%
# get all the hotels in the results dictionary
len(hotels["results"])
# Out:
# 20

# %%
#retrieve the name of the first hotel in the results dictionary
hotels["results"][0]["name"]
# Out:
# 'Paris'

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

hotel_df
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#               City Country  Max Temp    Lat     Lng  \
# 0           Liwale      TZ     71.85  -9.77   37.93
# 5           Najran      SA     73.40  17.49   44.13
# 6             Miri      MY     75.20   4.41  114.01
# 8            Kapaa      US     77.00  22.08 -159.32
# 9             Yako      BF     80.46  12.97   -2.27
# ..             ...     ...       ...    ...     ...
# 543        Huarmey      PE     70.32 -10.07  -78.15
# 544         Bafata      GW     76.98  12.17  -14.75
# 545  Pontian Kecil      MY     80.01   1.48  103.39
# 546        Cayenne      GF     80.60   4.93  -52.33
# 551           Gizo      SB     81.14  -8.10  156.84
#
#                                  Hotel Name
# 0                              Samoma Lodge
# 5                         محمد هادي ال فطيح
# 6                          Mega Hotel, Miri
# 8    Sheraton Kauai Resort at Coconut Beach
# 9                           Ecole de Sibega
# ..                                      ...
# 543                           Hotel Miramar
# 544
# 545                 SUNFLOWER EXPRESS HOTEL
# 546                         Hôtel Le Dronmi
# 551                      Imagination Island
#
# [196 rows x 6 columns]

# %% [markdown]
# # Create a Maximum Temperature Heatmap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
    dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
